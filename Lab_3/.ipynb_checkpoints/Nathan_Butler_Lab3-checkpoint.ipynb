# %% [markdown]
# ## Nathan Butler | 1001805566

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = pd.read_excel('Air_county.xlsx')
data.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2012            284        226             56
# 1  Alabama     Clay  2012            121         99             22
# 2  Alabama  Colbert  2012            283        222             55
# 3  Alabama   DeKalb  2012            361        282             74
# 4  Alabama   Elmore  2012            245        212             33
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    2               0                    0
# 1                                    0               0                    0
# 2                                    6               0                    0
# 3                                    5               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      112                   61          38        0
# 1               0       72                   56          35        0
# 2               0      136                   62          40        0
# 3               0      115                   64          40        0
# 4               0      100                   54          40        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10
# 0         0         210         0          74          0
# 1         0           0         0         121          0
# 2         0         209         0          74          0
# 3         0         320         0          41          0
# 4         0         245         0           0          0

# %%
for i in data.columns:
    print(i)
# Out:
# State
# County
# Year
# Days with AQI
# Good Days
# Moderate Days
# Unhealthy for Sensitive Groups Days
# Unhealthy Days
# Very Unhealthy Days
# Hazardous Days
# Max AQI
# 90th Percentile AQI
# Median AQI
# Days CO
# Days NO2
# Days Ozone
# Days SO2
# Days PM2.5
# Days PM10

# %% [markdown]
# ### 1.) Normalization and Standardization

# %% [markdown]
# #### Q1: Normalize the dataset using Min-Max normalization

# %%
column = [
    "Year",
"Days with AQI",
"Good Days",
"Moderate Days",
"Unhealthy for Sensitive Groups Days",
"Unhealthy Days",
"Very Unhealthy Days",
"Hazardous Days",
"Max AQI",
"90th Percentile AQI",
"Median AQI",
"Days CO",
"Days NO2",
"Days Ozone",
"Days SO2",
"Days PM2.5",
"Days PM10"
]


def min_max_scale(data, target_col):
    data = data.copy()
    data_mean = np.mean(data[target_col])
    MAX = np.max(data[target_col])
    MIN = np.min(data[target_col])
    mean_norm = ( (data[target_col] - MIN) / (MAX-MIN) )
    data[target_col] = mean_norm
    return data
min_max = min_max_scale(data, column)
min_max
# Out:
#         State      County      Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  0.520165       0.073423   0.058428       0.014478
# 1     Alabama        Clay  0.520165       0.031282   0.025595       0.005688
# 2     Alabama     Colbert  0.520165       0.073164   0.057394       0.014219
# 3     Alabama      DeKalb  0.520165       0.093330   0.072906       0.019131
# 4     Alabama      Elmore  0.520165       0.063340   0.054809       0.008532
# ...       ...         ...       ...            ...        ...            ...
# 1066  Wyoming    Sublette  0.520165       0.094623   0.053257       0.037487
# 1067  Wyoming  Sweetwater  0.520165       0.094623   0.055067       0.037487
# 1068  Wyoming       Teton  0.520165       0.094623   0.066701       0.027146
# 1069  Wyoming       Uinta  0.520165       0.094623   0.065667       0.028697
# 1070  Wyoming      Weston  0.520165       0.083506   0.083506       0.000000
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                                0.000517        0.000000
# 1                                0.000000        0.000000
# 2                                0.001551        0.000000
# 3                                0.001293        0.000000
# 4                                0.000000        0.000000
# ...                                   ...             ...
# 1066                             0.002327        0.001551
# 1067                             0.001810        0.000000
# 1068                             0.000776        0.000000
# 1069                             0.000259        0.000000
# 1070                             0.000000        0.000000
#
#       Very Unhealthy Days  Hazardous Days   Max AQI  90th Percentile AQI  \
# 0                0.000000             0.0  0.028956             0.015770
# 1                0.000000             0.0  0.018614             0.014478
# 2                0.000000             0.0  0.035160             0.016029
# 3                0.000000             0.0  0.029731             0.016546
# 4                0.000000             0.0  0.025853             0.013961
# ...                   ...             ...       ...                  ...
# 1066             0.000000             0.0  0.050931             0.020424
# 1067             0.000259             0.0  0.073423             0.019907
# 1068             0.000000             0.0  0.028438             0.017322
# 1069             0.000000             0.0  0.029731             0.018356
# 1070             0.000000             0.0  0.011375             0.009049
#
#       Median AQI   Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 0       0.009824  0.000000  0.000000    0.054292  0.000000    0.019131
# 1       0.009049  0.000000  0.000000    0.000000  0.000000    0.031282
# 2       0.010341  0.000000  0.000000    0.054033  0.000000    0.019131
# 3       0.010341  0.000000  0.000000    0.082730  0.000000    0.010600
# 4       0.010341  0.000000  0.000000    0.063340  0.000000    0.000000
# ...          ...       ...       ...         ...       ...         ...
# 1066    0.012410  0.000000  0.000000    0.084540  0.000000    0.010083
# 1067    0.012151  0.000000  0.000517    0.076525  0.002327    0.003102
# 1068    0.011375  0.000259  0.000000    0.090745  0.000000    0.003102
# 1069    0.011375  0.000000  0.000000    0.091003  0.000000    0.000000
# 1070    0.000000  0.000000  0.000000    0.011117  0.072389    0.000000
#
#       Days PM10
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ...         ...
# 1066   0.000000
# 1067   0.012151
# 1068   0.000517
# 1069   0.003619
# 1070   0.000000
#
# [1071 rows x 19 columns]

# %% [markdown]
# #### Q2: Standardize the dataset using Z-score standardization

# %%
column = [
"Days with AQI",
"Good Days",
"Moderate Days",
"Unhealthy for Sensitive Groups Days",
"Unhealthy Days",
"Very Unhealthy Days",
"Hazardous Days",
"Max AQI",
"90th Percentile AQI",
"Median AQI",
"Days CO",
"Days NO2",
"Days Ozone",
"Days SO2",
"Days PM2.5",
"Days PM10"
]
def standardize(data, target_col):
    data = data.copy()
    for col in data[target_col]:
        z_score = (data[col] - data[col].mean()) / data[col].std(ddof=0)
        data[col] = z_score
    return data
z_scores = standardize(data, column)
z_scores
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2012      -0.278880   0.014866      -0.339481
# 1     Alabama        Clay  2012      -2.097518  -1.550150      -0.979992
# 2     Alabama     Colbert  2012      -0.290037  -0.034426      -0.358319
# 3     Alabama      DeKalb  2012       0.580231   0.704952      -0.000387
# 4     Alabama      Elmore  2012      -0.714014  -0.157656      -0.772768
# ...       ...         ...   ...            ...        ...            ...
# 1066  Wyoming    Sublette  2012       0.636017  -0.231593       1.337150
# 1067  Wyoming  Sweetwater  2012       0.636017  -0.145333       1.337150
# 1068  Wyoming       Teton  2012       0.636017   0.409200       0.583608
# 1069  Wyoming       Uinta  2012       0.636017   0.359909       0.696639
# 1070  Wyoming      Weston  2012       0.156254   1.210193      -1.394440
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                               -0.499562       -0.191580
# 1                               -0.652493       -0.191580
# 2                               -0.193699       -0.191580
# 3                               -0.270165       -0.191580
# 4                               -0.652493       -0.191580
# ...                                   ...             ...
# 1066                             0.035698        0.572126
# 1067                            -0.117233       -0.191580
# 1068                            -0.423096       -0.191580
# 1069                            -0.576028       -0.191580
# 1070                            -0.652493       -0.191580
#
#       Very Unhealthy Days  Hazardous Days   Max AQI  90th Percentile AQI  \
# 0               -0.180833       -0.083454 -0.171800            -0.301242
# 1               -0.180833       -0.083454 -0.396586            -0.529153
# 2               -0.180833       -0.083454 -0.036929            -0.255660
# 3               -0.180833       -0.083454 -0.154941            -0.164496
# 4               -0.180833       -0.083454 -0.239236            -0.620318
# ...                   ...             ...       ...                  ...
# 1066            -0.180833       -0.083454  0.305869             0.519237
# 1067             1.775456       -0.083454  0.794778             0.428072
# 1068            -0.180833       -0.083454 -0.183040            -0.027749
# 1069            -0.180833       -0.083454 -0.154941             0.154579
# 1070            -0.180833       -0.083454 -0.553936            -1.486379
#
#       Median AQI   Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 0      -0.022252 -0.077882 -0.232549    0.355820 -0.246665   -0.298820
# 1      -0.255136 -0.077882 -0.232549   -1.401595 -0.246665    0.133612
# 2       0.133004 -0.077882 -0.232549    0.347451 -0.246665   -0.298820
# 3       0.133004 -0.077882 -0.232549    1.276370 -0.246665   -0.602442
# 4       0.133004 -0.077882 -0.232549    0.648722 -0.246665   -0.979670
# ...          ...       ...       ...         ...       ...         ...
# 1066    0.754027 -0.077882 -0.232549    1.334951 -0.246665   -0.620844
# 1067    0.676400 -0.077882 -0.149695    1.075523 -0.092084   -0.869262
# 1068    0.443516  0.019221 -0.232549    1.535798 -0.246665   -0.869262
# 1069    0.443516 -0.077882 -0.232549    1.544167 -0.246665   -0.979670
# 1070   -2.972113 -0.077882 -0.232549   -1.041744  4.562500   -0.979670
#
#       Days PM10  Bad_Air_Days
# 0     -0.263050             2
# 1     -0.263050             0
# 2     -0.263050             6
# 3     -0.263050             5
# 4     -0.263050             0
# ...         ...           ...
# 1066  -0.263050            15
# 1067   0.604028             8
# 1068  -0.226153             3
# 1069  -0.004771             1
# 1070  -0.263050             0
#
# [1071 rows x 20 columns]

# %%
min_max['Max AQI']
# Out:
# 0       0.028956
# 1       0.018614
# 2       0.035160
# 3       0.029731
# 4       0.025853
#           ...
# 1066    0.050931
# 1067    0.073423
# 1068    0.028438
# 1069    0.029731
# 1070    0.011375
# Name: Max AQI, Length: 1071, dtype: float64

# %%
z_scores['Max AQI']
# Out:
# 0      -0.171800
# 1      -0.396586
# 2      -0.036929
# 3      -0.154941
# 4      -0.239236
#           ...
# 1066    0.305869
# 1067    0.794778
# 1068   -0.183040
# 1069   -0.154941
# 1070   -0.553936
# Name: Max AQI, Length: 1071, dtype: float64

# %% [markdown]
# #### Q3: Compare the results of normalization and standardization on the Max AQI column. When would you prefer one technique over the other?

# %% [markdown]
# #### We would prefer the min_max scaling when the data is too spread out, and we would prefer the z_scores when we want to get a best estimate of the spread.

# %% [markdown]
# ### 2. Encoding Categorical Variables

# %% [markdown]
# #### Q4: Convert the categorical variable State into a numerical form using one-hot encoding. How many new columns are created, and what are their names?

# %%
unique_list=list()
for unique in data['State'].unique():
    unique_list.append(unique)

# %%
def one_hot_encoding(data, column_name, column_values):
    data = data.copy()
    # Create binary columns only for string-type categories
    for dwelling in column_values:
        data[f"{dwelling}"] = (data[column_name] == dwelling).astype(int)
    return data
one_hot = one_hot_encoding(data, 'State', unique_list)
print("There are now 73 columns! Listed below are their names:")
for x in one_hot.columns:
    print(x)
# Out:
# There are now 73 columns! Listed below are their names:
# State
# County
# Year
# Days with AQI
# Good Days
# Moderate Days
# Unhealthy for Sensitive Groups Days
# Unhealthy Days
# Very Unhealthy Days
# Hazardous Days
# Max AQI
# 90th Percentile AQI
# Median AQI
# Days CO
# Days NO2
# Days Ozone
# Days SO2
# Days PM2.5
# Days PM10
# Bad_Air_Days
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Country Of Mexico
# Delaware
# District Of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Puerto Rico
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virgin Islands
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %% [markdown]
# #### Q5: Use label encoding for the County column. What are the numerical labels assigned to each county?

# %%
def label_encoding(data):
    data = data.copy()
    # We create a map to hold the idx, and unique case values.
    loc_map = {} 
    for idx, case in enumerate(data['County'].unique()):
        loc_map[case] = idx
    data['County'] = data['County'].map(loc_map)
    return data
state_label = label_encoding(data)
print("For each county, the numerical labels range from 0 to 818.")
state_label['County']
# Out:
# For each county, the numerical labels range from 0 to 818.
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#        ...
# 1066    814
# 1067    815
# 1068    816
# 1069    817
# 1070    818
# Name: County, Length: 1071, dtype: int64

# %% [markdown]
# #### Q6: Discuss the impact of using one-hot encoding vs label encoding on the model performance when the categorical variables are used in regression analysis.

# %% [markdown]
# >##### If we are talking about model performance, label encoding would be the best fit in this dataset because we can make predictions on the counts of each County. For the State column, one-hot encoding works well here because with regression analysis there we would try and target those features.

# %% [markdown]
# ### 3. Discretization and Binning

# %% [markdown]
# #### Q7: Bin the Max AQI column into 4 categories: "Low", "Moderate", "High", and "Very High" using equal-width binning. How many rows fall into each category?

# %%
import math
minn=round(min(z_scores['Max AQI']))
very_high=max(z_scores['Max AQI'])
moderate=np.mean(z_scores['Max AQI'])
high=(very_high - moderate)
minn
# Out:
# -1

# %%
import math
def id_outlier(z_scores):
    
    minn=round(min(z_scores['Max AQI']))
    very_high=round(max(z_scores['Max AQI']))
    moderate=round(math.exp(np.mean(z_scores['Max AQI'])))
    high=(very_high - moderate)
    
    for col, scores in z_scores['Max AQI'].items():
        Q1 = scores[int(scores) < moderate] # Low
        Q2 = scores[(int(scores) >= abs(moderate)) & (int(scores) < high)] # Moderate
        Q3 = scores[(int(scores) >= abs(moderate)) & (int(scores) < very_high)] # High
        Q4 = scores[(int(scores) > high) & (int(scores) <= very_high)] # Very High
        z_scores["Q1"] = Q1
        z_scores["Q2"] = Q2
        z_scores["Q3"] = Q3
        z_scores["Q4"] = Q4
    return z_scores
binning = id_outlier(z_scores)
binning
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 19
#      17         z_scores["Q4"] = Q4
#      18     return z_scores
# ---> 19 binning = id_outlier(z_scores)
#      20 binning
#
# Cell In[25], line 10, in id_outlier(z_scores)
#       7 high=(very_high - moderate)
#       9 for col, scores in z_scores['Max AQI'].items():
# ---> 10     Q1 = scores[int(scores) < moderate] # Low
#      11     Q2 = scores[(int(scores) >= abs(moderate)) & (int(scores) < high)] # Moderate
#      12     Q3 = scores[(int(scores) >= abs(moderate)) & (int(scores) < very_high)] # High
#
# TypeError: 'float' object is not subscriptable

# %%
for x,y in z_scores['Max AQI'].items():
    print(x,y)
# Out:
# 0 -0.17180041116720607
# 1 -0.3965859958719616
# 2 -0.03692906034435276
# 3 -0.1549414923143494
# 4 -0.2392360865786327
# 5 -0.31229140160767827
# 6 -0.2560950054314894
# 7 0.1653779658899272
# 8 -0.475260950518626
# 9 0.024886975449455007
# 10 -0.09312545652054163
# 11 -0.22799680734339495
# 12 -0.07626653766768497
# 13 -0.23361644696101383
# 14 0.04174589430231167
# 15 -0.36848779778386714
# 16 -0.2785735639019649
# 17 -0.5988930221062415
# 18 -0.2392360865786327
# 19 -0.475260950518626
# 20 0.4463599467708716
# 21 -0.14370221307911163
# 22 -0.3010521223724405
# 23 -0.08750581690292275
# 24 -0.6831876163705248
# 25 -0.48650022975386376
# 26 -0.12684329422625495
# 27 -0.05378797919720942
# 28 0.3227278751832561
# 29 -0.1549414923143494
# 30 0.7048633691813404
# 31 -0.1493218526967305
# 32 -0.09312545652054163
# 33 0.002408416978979455
# 34 2.5368658845250978
# 35 -0.1998986092553005
# 36 -0.17180041116720607
# 37 0.13166012818421388
# 38 -0.36286815816624823
# 39 -0.3909663562543427
# 40 -0.05378797919720942
# 41 0.07546373200802499
# 42 -0.40782527510719935
# 43 -0.3853467166367238
# 44 -0.374107437401486
# 45 -0.03692906034435276
# 46 -0.44716275243053155
# 47 -0.05378797919720942
# 48 -0.4303038335776749
# 49 0.04174589430231167
# 50 0.3227278751832561
# 51 0.04736553391993056
# 52 0.10356193009611943
# 53 -0.17742005078482495
# 54 0.07546373200802499
# 55 0.2440529205365916
# 56 0.07546373200802499
# 57 0.33396715441849384
# 58 0.06422445277278722
# #### Q8: Check the skewness of the Max AQI and Median AQI columns. Which of these columns is highly skewed?

# %%
import matplotlib.pyplot as plt

def MAX_AQI():
    plt.figure(figsize=(8,6))
    plt.bar(z_scores['Max AQI'], height=z_scores['Max AQI'].values)
    plt.show()
    
    
def MED_AQI():
    plt.figure(figsize=(8,6))
    plt.bar(z_scores['Median AQI'], height=z_scores['Median AQI'].values)
    plt.show()
    
MAX_AQI()
MED_AQI()
print("It seems that the Median AQI is highly skewed.")
# Out:
# It seems that the Median AQI is highly skewed.

# %% [markdown]
# #### Q9: Apply a log transformation to the Max AQI column to handle its skewness. How does this affect the skewness?

# %%
def log_trans(data, target_col):
    data = data.copy()
    
    data[target_col] = np.log(data[target_col])
    
    return data

logg = log_trans(data, 'Max AQI')
logg
# Use matplotlib func
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2012            284        226             56
# 1     Alabama        Clay  2012            121         99             22
# 2     Alabama     Colbert  2012            283        222             55
# 3     Alabama      DeKalb  2012            361        282             74
# 4     Alabama      Elmore  2012            245        212             33
# ...       ...         ...   ...            ...        ...            ...
# 1066  Wyoming    Sublette  2012            366        206            145
# 1067  Wyoming  Sweetwater  2012            366        213            145
# 1068  Wyoming       Teton  2012            366        258            105
# 1069  Wyoming       Uinta  2012            366        254            111
# 1070  Wyoming      Weston  2012            323        323              0
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                                       2               0
# 1                                       0               0
# 2                                       6               0
# 3                                       5               0
# 4                                       0               0
# ...                                   ...             ...
# 1066                                    9               6
# 1067                                    7               0
# 1068                                    3               0
# 1069                                    1               0
# 1070                                    0               0
#
#       Very Unhealthy Days  Hazardous Days   Max AQI  90th Percentile AQI  \
# 0                       0               0  4.718499                   61
# 1                       0               0  4.276666                   56
# 2                       0               0  4.912655                   62
# 3                       0               0  4.744932                   64
# 4                       0               0  4.605170                   54
# ...                   ...             ...       ...                  ...
# 1066                    0               0  5.283204                   79
# 1067                    1               0  5.648974                   77
# 1068                    0               0  4.700480                   67
# 1069                    0               0  4.744932                   71
# 1070                    0               0  3.784190                   35
#
#       Median AQI  Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 0             38        0         0         210         0          74
# 1             35        0         0           0         0         121
# 2             40        0         0         209         0          74
# 3             40        0         0         320         0          41
# 4             40        0         0         245         0           0
# ...          ...      ...       ...         ...       ...         ...
# 1066          48        0         0         327         0          39
# 1067          47        0         2         296         9          12
# 1068          44        1         0         351         0          12
# 1069          44        0         0         352         0           0
# 1070           0        0         0          43       280           0
#
#       Days PM10  Bad_Air_Days
# 0             0             2
# 1             0             0
# 2             0             6
# 3             0             5
# 4             0             0
# ...         ...           ...
# 1066          0            15
# 1067         47             8
# 1068          2             3
# 1069         14             1
# 1070          0             0
#
# [1071 rows x 20 columns]

# %% [markdown]
# #### Q10: After applying the log transformation, what changes do you observe in the distribution of the Max AQI data?

# %%
def LOG_AQI(data):
    plt.figure(figsize=(8,6))
    plt.bar(data['Max AQI'], height=logg['Max AQI'].values)
    plt.show()
    
LOG_AQI(logg)
print("After applying the log transformation, the distribution is more uniform.")
# Out:
# After applying the log transformation, the distribution is more uniform.

# %% [markdown]
# ### 5. Feature Engineering

# %% [markdown]
# #### Q11: Create a new feature called Bad_Air_Days, which is the sum of Unhealthy for Sensitive Groups Days, Unhealthy Days, Very Unhealthy Days, and Hazardous Days. How many counties have more than 10 Bad_Air_Days?

# %%
cols = ["Unhealthy for Sensitive Groups Days", "Unhealthy Days", "Very Unhealthy Days", "Hazardous Days"]
def feature(data, cols):
    data['Bad_Air_Days'] = sum([data[col] for col in cols])

    return data

feature(z_scores, cols)
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0     Alabama     Baldwin  2012      -0.278880   0.014866      -0.339481
# 1     Alabama        Clay  2012      -2.097518  -1.550150      -0.979992
# 2     Alabama     Colbert  2012      -0.290037  -0.034426      -0.358319
# 3     Alabama      DeKalb  2012       0.580231   0.704952      -0.000387
# 4     Alabama      Elmore  2012      -0.714014  -0.157656      -0.772768
# ...       ...         ...   ...            ...        ...            ...
# 1066  Wyoming    Sublette  2012       0.636017  -0.231593       1.337150
# 1067  Wyoming  Sweetwater  2012       0.636017  -0.145333       1.337150
# 1068  Wyoming       Teton  2012       0.636017   0.409200       0.583608
# 1069  Wyoming       Uinta  2012       0.636017   0.359909       0.696639
# 1070  Wyoming      Weston  2012       0.156254   1.210193      -1.394440
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 0                               -0.499562       -0.191580
# 1                               -0.652493       -0.191580
# 2                               -0.193699       -0.191580
# 3                               -0.270165       -0.191580
# 4                               -0.652493       -0.191580
# ...                                   ...             ...
# 1066                             0.035698        0.572126
# 1067                            -0.117233       -0.191580
# 1068                            -0.423096       -0.191580
# 1069                            -0.576028       -0.191580
# 1070                            -0.652493       -0.191580
#
#       Very Unhealthy Days  Hazardous Days   Max AQI  90th Percentile AQI  \
# 0               -0.180833       -0.083454 -0.171800            -0.301242
# 1               -0.180833       -0.083454 -0.396586            -0.529153
# 2               -0.180833       -0.083454 -0.036929            -0.255660
# 3               -0.180833       -0.083454 -0.154941            -0.164496
# 4               -0.180833       -0.083454 -0.239236            -0.620318
# ...                   ...             ...       ...                  ...
# 1066            -0.180833       -0.083454  0.305869             0.519237
# 1067             1.775456       -0.083454  0.794778             0.428072
# 1068            -0.180833       -0.083454 -0.183040            -0.027749
# 1069            -0.180833       -0.083454 -0.154941             0.154579
# 1070            -0.180833       -0.083454 -0.553936            -1.486379
#
#       Median AQI   Days CO  Days NO2  Days Ozone  Days SO2  Days PM2.5  \
# 0      -0.022252 -0.077882 -0.232549    0.355820 -0.246665   -0.298820
# 1      -0.255136 -0.077882 -0.232549   -1.401595 -0.246665    0.133612
# 2       0.133004 -0.077882 -0.232549    0.347451 -0.246665   -0.298820
# 3       0.133004 -0.077882 -0.232549    1.276370 -0.246665   -0.602442
# 4       0.133004 -0.077882 -0.232549    0.648722 -0.246665   -0.979670
# ...          ...       ...       ...         ...       ...         ...
# 1066    0.754027 -0.077882 -0.232549    1.334951 -0.246665   -0.620844
# 1067    0.676400 -0.077882 -0.149695    1.075523 -0.092084   -0.869262
# 1068    0.443516  0.019221 -0.232549    1.535798 -0.246665   -0.869262
# 1069    0.443516 -0.077882 -0.232549    1.544167 -0.246665   -0.979670
# 1070   -2.972113 -0.077882 -0.232549   -1.041744  4.562500   -0.979670
#
#       Days PM10  Bad_Air_Days
# 0     -0.263050     -0.955429
# 1     -0.263050     -1.108361
# 2     -0.263050     -0.649566
# 3     -0.263050     -0.726032
# 4     -0.263050     -1.108361
# ...         ...           ...
# 1066  -0.263050      0.343537
# 1067   0.604028      1.383189
# 1068  -0.226153     -0.878964
# 1069  -0.004771     -1.031895
# 1070  -0.263050     -1.108361
#
# [1071 rows x 20 columns]

# %% [markdown]
# ### 6. Multicollinearity

# %%
# Basic correlation
# z_scores.select_dtypes(include='number').corr()

# %% [markdown]
# #### Q12: Calculate the correlation matrix for all numeric variables. Which variables are highly correlated with each other?

# %%
def seaborn_heatmap(data, cmap="coolwarm", fmt=".2f"):
    """
    Plot a correlation heatmap for the given numeric vars in `data`.
    """
    # 1. compute the correlation matrix
    corr = data.select_dtypes(include='number').corr()
    
    # 2. draw the heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(
        corr,
        annot=True,        # show numbers in each cell
        fmt=fmt,           # formatting for the annotations
        cmap=cmap,
        square=True,
        linewidths=0.5,
        cbar_kws={"shrink": 0.8}
    )
    
    # 3. tidy up the axes
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.title("Correlation Heatmap")
    plt.tight_layout()
    plt.show()
seaborn_heatmap(z_scores)

# %% [markdown]
# ### Highly Correlated Variables:
# >### (Days with AQI & Good Days)
# >### (90th Percentile AQI & Moderate Days)
# >### (90th Percentile AQI & Unhealthy for Sensitive Groups Days)
# >### (Median AQI & Moderate Days)
# >### (Hazardous Days & Max AQI)
# >### (90th Percentile AQI & Median AQI)
# >### (Unhealthy for Sensitive Groups Days & Bad_Air_Days)
# >### (Unhealthy Days & Bad_Air_Days)
# >### (Very Unhealthy Days & Bad_Air_Days)

# %% [markdown]
# #### Q13: Based on the correlation matrix, identify pairs of features that might cause multicollinearity. How could you address this issue?

# %% [markdown]
# ### Pairs that may cause multicollinearity:
# >### (Unhealthy Days & Bad_Air_Days)
# >### (90th Percentile AQI & Median AQI)
# >### (Hazardous Days & Max AQI)
#
#
# ### We can address this issue by omitting the pairs from showing up on the matrix.

# %% [markdown]
# #### Q14: Remove one of the highly correlated features from the dataset. Recompute the correlation matrix and compare it with the original one. What changes do you observe?

# %%
one_drop = z_scores.drop(['Median AQI', '90th Percentile AQI'], axis=1)
# Basic correlation
# one_drop.select_dtypes(include='number').corr()
seaborn_heatmap(one_drop)

# %% [markdown]
# ### I notice that the heatmap is easier to read, and I can draw my attention to a pattern. Before, there was not mmuch of a pattern in the matrix, so it was hard to focus on a feature pair. With this adjustment, I would investigate the correlation between the emmissions measurements (CO, NO2, Ozone, etc) and the rest of the 'Days' categories.
